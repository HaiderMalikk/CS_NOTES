# %% [markdown]
# Tests

# %%
# %pip install matplotlib
# Out:
# Collecting matplotlib
#   Using cached matplotlib-3.10.1-cp310-cp310-macosx_11_0_arm64.whl (8.0 MB)
# Collecting pyparsing>=2.3.1
#   Using cached pyparsing-3.2.3-py3-none-any.whl (111 kB)
# Collecting cycler>=0.10
#   Using cached cycler-0.12.1-py3-none-any.whl (8.3 kB)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Collecting numpy>=1.23
#   Using cached numpy-2.2.4-cp310-cp310-macosx_14_0_arm64.whl (5.4 MB)
# Collecting contourpy>=1.0.1
#   Using cached contourpy-1.3.1-cp310-cp310-macosx_11_0_arm64.whl (253 kB)
# Collecting fonttools>=4.22.0
#   Using cached fonttools-4.56.0-cp310-cp310-macosx_10_9_universal2.whl (2.8 MB)
# Collecting pillow>=8
#   Using cached pillow-11.1.0-cp310-cp310-macosx_11_0_arm64.whl (3.1 MB)
# Collecting kiwisolver>=1.3.1
#   Using cached kiwisolver-1.4.8-cp310-cp310-macosx_11_0_arm64.whl (65 kB)
# Requirement already satisfied: packaging>=20.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from matplotlib) (24.2)
# Requirement already satisfied: six>=1.5 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Installing collected packages: pyparsing, pillow, numpy, kiwisolver, fonttools, cycler, contourpy, matplotlib
# Successfully installed contourpy-1.3.1 cycler-0.12.1 fonttools-4.56.0 kiwisolver-1.4.8 matplotlib-3.10.1 numpy-2.2.4 pillow-11.1.0 pyparsing-3.2.3
#
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import numpy as np
import matplotlib.pyplot as plt

# Randomly generate grayscale image data (28x28 like MNIST)
sample_images = np.random.rand(5, 28, 28)  # 5 images of 28x28 pixels

fig, axes = plt.subplots(1, 5, figsize=(10, 3))
for i in range(5):
    axes[i].imshow(sample_images[i], cmap="gray")
    axes[i].axis("off")
plt.show()

# %%
# %pip install tensorflow
# %pip install tensorflow-metal
# %pip install keras_cv matplotlib diffusers transformers torch scipy
# Out:
# Requirement already satisfied: tensorflow in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (2.19.0)
# Requirement already satisfied: absl-py>=1.0.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (2.2.1)
# Requirement already satisfied: flatbuffers>=24.3.25 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (25.2.10)
# Requirement already satisfied: astunparse>=1.6.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (1.6.3)
# Requirement already satisfied: tensorboard~=2.19.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (2.19.0)
# Requirement already satisfied: six>=1.12.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (1.17.0)
# Requirement already satisfied: opt-einsum>=2.3.2 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (3.4.0)
# Requirement already satisfied: google-pasta>=0.1.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (0.2.0)
# Requirement already satisfied: setuptools in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (65.5.0)
# Requirement already satisfied: termcolor>=1.1.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (2.5.0)
# Requirement already satisfied: libclang>=13.0.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (18.1.1)
# Requirement already satisfied: packaging in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (24.2)
# Requirement already satisfied: ml-dtypes<1.0.0,>=0.5.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (0.5.1)
# Requirement already satisfied: h5py>=3.11.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (3.13.0)
# Requirement already satisfied: tensorflow-io-gcs-filesystem>=0.23.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (0.37.1)
# Requirement already satisfied: wrapt>=1.11.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (1.17.2)
# Requirement already satisfied: gast!=0.5.0,!=0.5.1,!=0.5.2,>=0.2.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (0.6.0)
# Requirement already satisfied: grpcio<2.0,>=1.24.3 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (1.71.0)
# Requirement already satisfied: protobuf!=4.21.0,!=4.21.1,!=4.21.2,!=4.21.3,!=4.21.4,!=4.21.5,<6.0.0dev,>=3.20.3 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (3.20.3)
# Requirement already satisfied: requests<3,>=2.21.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (2.32.3)
# Requirement already satisfied: numpy<2.2.0,>=1.26.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (2.1.3)
# Requirement already satisfied: typing-extensions>=3.6.6 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (4.13.0)
# Requirement already satisfied: keras>=3.5.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow) (3.9.1)
# Requirement already satisfied: wheel<1.0,>=0.23.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from astunparse>=1.6.0->tensorflow) (0.45.1)
# Requirement already satisfied: rich in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (14.0.0)
# Requirement already satisfied: optree in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (0.14.1)
# Requirement already satisfied: namex in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from keras>=3.5.0->tensorflow) (0.0.8)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (2025.1.31)
# Requirement already satisfied: idna<4,>=2.5 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from requests<3,>=2.21.0->tensorflow) (3.10)
# Requirement already satisfied: tensorboard-data-server<0.8.0,>=0.7.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (0.7.2)
# Requirement already satisfied: markdown>=2.6.8 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (3.7)
# Requirement already satisfied: werkzeug>=1.0.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorboard~=2.19.0->tensorflow) (3.1.3)
# Requirement already satisfied: MarkupSafe>=2.1.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from werkzeug>=1.0.1->tensorboard~=2.19.0->tensorflow) (3.0.2)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from rich->keras>=3.5.0->tensorflow) (2.19.1)
# Requirement already satisfied: mdurl~=0.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras>=3.5.0->tensorflow) (0.1.2)
#
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: tensorflow-metal in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (1.2.0)
# Requirement already satisfied: wheel~=0.35 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow-metal) (0.45.1)
# Requirement already satisfied: six>=1.15.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow-metal) (1.17.0)
#
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.
# Requirement already satisfied: keras_cv in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (0.9.0)
# Requirement already satisfied: matplotlib in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (3.10.1)
# Collecting diffusers
#   Using cached diffusers-0.32.2-py3-none-any.whl (3.2 MB)
# Collecting transformers
#   Using cached transformers-4.50.3-py3-none-any.whl (10.2 MB)
# Requirement already satisfied: torch in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (2.6.0)
# Requirement already satisfied: scipy in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (1.15.2)
# Requirement already satisfied: keras-core in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from keras_cv) (0.1.7)
# Requirement already satisfied: kagglehub in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from keras_cv) (0.3.10)
# Requirement already satisfied: tensorflow-datasets in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from keras_cv) (4.9.8)
# Requirement already satisfied: regex in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from keras_cv) (2024.11.6)
# Requirement already satisfied: absl-py in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from keras_cv) (2.2.1)
# Requirement already satisfied: packaging in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from keras_cv) (24.2)
# Requirement already satisfied: fonttools>=4.22.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from matplotlib) (4.56.0)
# Requirement already satisfied: python-dateutil>=2.7 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: numpy>=1.23 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from matplotlib) (2.1.3)
# Requirement already satisfied: kiwisolver>=1.3.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from matplotlib) (1.4.8)
# Requirement already satisfied: contourpy>=1.0.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from matplotlib) (1.3.1)
# Requirement already satisfied: pyparsing>=2.3.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from matplotlib) (3.2.3)
# Requirement already satisfied: cycler>=0.10 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: pillow>=8 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from matplotlib) (11.1.0)
# Requirement already satisfied: requests in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from diffusers) (2.32.3)
# Requirement already satisfied: filelock in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from diffusers) (3.18.0)
# Requirement already satisfied: safetensors>=0.3.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from diffusers) (0.5.3)
# Requirement already satisfied: importlib-metadata in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from diffusers) (8.6.1)
# Requirement already satisfied: huggingface-hub>=0.23.2 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from diffusers) (0.29.3)
# Collecting tokenizers<0.22,>=0.21
#   Using cached tokenizers-0.21.1-cp39-abi3-macosx_11_0_arm64.whl (2.7 MB)
# Requirement already satisfied: tqdm>=4.27 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from transformers) (4.67.1)
# Requirement already satisfied: pyyaml>=5.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from transformers) (6.0.2)
# Requirement already satisfied: sympy==1.13.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from torch) (1.13.1)
# Requirement already satisfied: jinja2 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from torch) (2025.3.1)
# Requirement already satisfied: networkx in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from torch) (3.4.2)
# Requirement already satisfied: typing-extensions>=4.10.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from torch) (4.13.0)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: six>=1.5 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)
# Requirement already satisfied: zipp>=3.20 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from importlib-metadata->diffusers) (3.21.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from jinja2->torch) (3.0.2)
# Requirement already satisfied: namex in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from keras-core->keras_cv) (0.0.8)
# Requirement already satisfied: h5py in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from keras-core->keras_cv) (3.13.0)
# Requirement already satisfied: dm-tree in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from keras-core->keras_cv) (0.1.9)
# Requirement already satisfied: rich in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from keras-core->keras_cv) (14.0.0)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from requests->diffusers) (2025.1.31)
# Requirement already satisfied: idna<4,>=2.5 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from requests->diffusers) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from requests->diffusers) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from requests->diffusers) (3.4.1)
# Requirement already satisfied: wrapt in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (1.17.2)
# Requirement already satisfied: psutil in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (7.0.0)
# Requirement already satisfied: termcolor in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (2.5.0)
# Requirement already satisfied: protobuf>=3.20 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (3.20.3)
# Requirement already satisfied: immutabledict in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (4.2.1)
# Requirement already satisfied: promise in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (2.3)
# Requirement already satisfied: toml in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (0.10.2)
# Requirement already satisfied: etils[edc,enp,epath,epy,etree]>=1.6.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (1.12.2)
# Requirement already satisfied: tensorflow-metadata in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (1.16.1)
# Requirement already satisfied: pyarrow in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (19.0.1)
# Requirement already satisfied: simple_parsing in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from tensorflow-datasets->keras_cv) (0.1.7)
# Requirement already satisfied: importlib_resources in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0->tensorflow-datasets->keras_cv) (6.5.2)
# Requirement already satisfied: einops in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from etils[edc,enp,epath,epy,etree]>=1.6.0->tensorflow-datasets->keras_cv) (0.8.1)
# Requirement already satisfied: attrs>=18.2.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from dm-tree->keras-core->keras_cv) (25.3.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from rich->keras-core->keras_cv) (3.0.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from rich->keras-core->keras_cv) (2.19.1)
# Requirement already satisfied: docstring-parser<1.0,>=0.15 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from simple_parsing->tensorflow-datasets->keras_cv) (0.16)
# Requirement already satisfied: mdurl~=0.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from markdown-it-py>=2.2.0->rich->keras-core->keras_cv) (0.1.2)
# Installing collected packages: tokenizers, diffusers, transformers
# Successfully installed diffusers-0.32.2 tokenizers-0.21.1 transformers-4.50.3
#
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip
# Note: you may need to restart the kernel to use updated packages.

# %%
import tensorflow as tf

# Check if TensorFlow detects the GPU
print("Num GPUs Available:", len(tf.config.list_physical_devices('GPU')))
print("GPU Devices:", tf.config.list_physical_devices('GPU'))

# Check if TensorFlow is running on Metal
tf.debugging.set_log_device_placement(True)

# Force TensorFlow to run on GPU if available
device = "/GPU:0" if tf.config.list_physical_devices('GPU') else "/CPU:0"
print("Using device:", device)

# Perform a simple matrix multiplication to see if it runs on GPU
import time
with tf.device(device):
    a = tf.random.normal([1000, 1000])
    b = tf.random.normal([1000, 1000])
    
    start = time.time()
    c = tf.matmul(a, b)
    print("Computation time:", time.time() - start)
# Out:
# Num GPUs Available: 1
# GPU Devices: [PhysicalDevice(name='/physical_device:GPU:0', device_type='GPU')]
# Using device: /GPU:0
# input: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# shape: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:GPU:0
# output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomStandardNormal in device /job:localhost/replica:0/task:0/device:GPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# AddV2: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op _EagerConst in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op RandomStandardNormal in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op Mul in device /job:localhost/replica:0/task:0/device:GPU:0
# Executing op AddV2 in device /job:localhost/replica:0/task:0/device:GPU:0
# a: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# b: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# product_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# Executing op MatMul in device /job:localhost/replica:0/task:0/device:GPU:0
# Computation time: 0.027293920516967773
# 2025-03-31 15:33:51.431565: I metal_plugin/src/device/metal_device.cc:1154] Metal device set to: Apple M2 Pro
# 2025-03-31 15:33:51.431800: I metal_plugin/src/device/metal_device.cc:296] systemMemory: 16.00 GB
# 2025-03-31 15:33:51.431812: I metal_plugin/src/device/metal_device.cc:313] maxCacheSize: 5.33 GB
# 2025-03-31 15:33:51.431871: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:305] Could not identify NUMA node of platform GPU ID 0, defaulting to 0. Your kernel may not have been built with NUMA support.
# 2025-03-31 15:33:51.431890: I tensorflow/core/common_runtime/pluggable_device/pluggable_device_factory.cc:271] Created TensorFlow device (/job:localhost/replica:0/task:0/device:GPU:0 with 0 MB memory) -> physical PluggableDevice (device: 0, name: METAL, pci bus id: <undefined>)
# 2025-03-31 15:33:51.445881: I tensorflow/core/common_runtime/placer.cc:125] input: (_Arg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-31 15:33:51.445913: I tensorflow/core/common_runtime/placer.cc:125] _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.445917: I tensorflow/core/common_runtime/placer.cc:125] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.451711: I tensorflow/core/common_runtime/placer.cc:125] input: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.451725: I tensorflow/core/common_runtime/placer.cc:125] _EagerConst: (_EagerConst): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.451729: I tensorflow/core/common_runtime/placer.cc:125] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.458237: I tensorflow/core/common_runtime/placer.cc:125] shape: (_DeviceArg): /job:localhost/replica:0/task:0/device:CPU:0
# 2025-03-31 15:33:51.458246: I tensorflow/core/common_runtime/placer.cc:125] RandomStandardNormal: (RandomStandardNormal): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.458250: I tensorflow/core/common_runtime/placer.cc:125] output_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.529236: I tensorflow/core/common_runtime/placer.cc:125] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.529249: I tensorflow/core/common_runtime/placer.cc:125] y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.529257: I tensorflow/core/common_runtime/placer.cc:125] Mul: (Mul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.529261: I tensorflow/core/common_runtime/placer.cc:125] z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.539146: I tensorflow/core/common_runtime/placer.cc:125] x: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.539165: I tensorflow/core/common_runtime/placer.cc:125] y: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.539173: I tensorflow/core/common_runtime/placer.cc:125] AddV2: (AddV2): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.539176: I tensorflow/core/common_runtime/placer.cc:125] z_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.548918: I tensorflow/core/common_runtime/placer.cc:125] a: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.548959: I tensorflow/core/common_runtime/placer.cc:125] b: (_Arg): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.548968: I tensorflow/core/common_runtime/placer.cc:125] MatMul: (MatMul): /job:localhost/replica:0/task:0/device:GPU:0
# 2025-03-31 15:33:51.548973: I tensorflow/core/common_runtime/placer.cc:125] product_RetVal: (_Retval): /job:localhost/replica:0/task:0/device:GPU:0

# %%
import tensorflow as tf
print(tf.__version__)
# Out:
# 2.19.0

# %%
import keras_cv
from tensorflow import keras
import matplotlib.pyplot as plt

# Initialize Stable Diffusion model
model = keras_cv.models.StableDiffusion(img_width=512, img_height=512)

# Generate images from text prompt
images = model.text_to_image("A futuristic city at sunset", batch_size=3)

# Display images
def plot_images(images):
    plt.figure(figsize=(20, 20))
    for i in range(len(images)):
        ax = plt.subplot(1, len(images), i + 1)
        plt.imshow(images[i])
        plt.axis("off")
    plt.show()

plot_images(images)
