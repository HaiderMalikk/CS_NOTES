# %%
# Import libraries
import transformers
from transformers import pipeline

# Example 1: Sentiment Analysis with LLM
sentiment_analyzer = pipeline("sentiment-analysis")
result = sentiment_analyzer("I really enjoyed using this NLP model!")
print(f"Sentiment Analysis Result: {result}")

# Example 2: Text Generation with LLM
text_generator = pipeline("text-generation", model="gpt2", max_length=50)
generated_text = text_generator("Natural Language Processing is")
print(f"Generated Text: {generated_text[0]['generated_text']}")

# Example 3: Question Answering with LLM
qa_pipeline = pipeline("question-answering")
context = "Large Language Models are advanced NLP systems that can perform multiple language tasks."
question = "What are Large Language Models?"
answer = qa_pipeline(question=question, context=context)
print(f"Answer: {answer['answer']}")
# Out:
# No model was supplied, defaulted to distilbert/distilbert-base-uncased-finetuned-sst-2-english and revision 714eb0f (https://huggingface.co/distilbert/distilbert-base-uncased-finetuned-sst-2-english).
# Using a pipeline without specifying a model name and revision in production is not recommended.
# Device set to use mps:0
# Sentiment Analysis Result: [{'label': 'POSITIVE', 'score': 0.9994862079620361}]
# Device set to use mps:0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[3], line 12
#      10 # Example 2: Text Generation with LLM
#      11 text_generator = pipeline("text-generation", model="gpt2", max_length=50)
# ---> 12 generated_text = text_generator("Natural Language Processing is")
#      13 print(f"Generated Text: {generated_text[0]['generated_text']}")
#      15 # Example 3: Question Answering with LLM
#
# File ~/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages/transformers/pipelines/text_generation.py:287, in TextGenerationPipeline.__call__(self, text_inputs, **kwargs)
#     285             else:
#     286                 return super().__call__(list(chats), **kwargs)
# --> 287 return super().__call__(text_inputs, **kwargs)
#
# File ~/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages/transformers/pipelines/base.py:1371, in Pipeline.__call__(self, inputs, num_workers, batch_size, *args, **kwargs)
#    1363     return next(
#    1364         iter(
#    1365             self.get_iterator(
#    (...)
#    1368         )
#    1369     )
#    1370 else:
# -> 1371     return self.run_single(inputs, preprocess_params, forward_params, postprocess_params)
#
# File ~/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages/transformers/pipelines/base.py:1378, in Pipeline.run_single(self, inputs, preprocess_params, forward_params, postprocess_params)
#    1376 def run_single(self, inputs, preprocess_params, forward_params, postprocess_params):
#    1377     model_inputs = self.preprocess(inputs, **preprocess_params)
# -> 1378     model_outputs = self.forward(model_inputs, **forward_params)
#    1379     outputs = self.postprocess(model_outputs, **postprocess_params)
#    1380     return outputs
#
# File ~/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages/transformers/pipelines/base.py:1278, in Pipeline.forward(self, model_inputs, **forward_params)
#    1276     with inference_context():
#    1277         model_inputs = self._ensure_tensor_on_device(model_inputs, device=self.device)
# -> 1278         model_outputs = self._forward(model_inputs, **forward_params)
#    1279         model_outputs = self._ensure_tensor_on_device(model_outputs, device=torch.device("cpu"))
#    1280 else:
#
# File ~/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages/transformers/pipelines/text_generation.py:385, in TextGenerationPipeline._forward(self, model_inputs, **generate_kwargs)
#     382 if "generation_config" not in generate_kwargs:
#     383     generate_kwargs["generation_config"] = self.generation_config
# --> 385 output = self.model.generate(input_ids=input_ids, attention_mask=attention_mask, **generate_kwargs)
#     387 if isinstance(output, ModelOutput):
#     388     generated_sequence = output.sequences
#
# File ~/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages/torch/utils/_contextlib.py:116, in context_decorator.<locals>.decorate_context(*args, **kwargs)
#     113 @functools.wraps(func)
#     114 def decorate_context(*args, **kwargs):
#     115     with ctx_factory():
# --> 116         return func(*args, **kwargs)
#
# File ~/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages/transformers/generation/utils.py:2326, in GenerationMixin.generate(self, inputs, generation_config, logits_processor, stopping_criteria, prefix_allowed_tokens_fn, synced_gpus, assistant_model, streamer, negative_prompt_ids, negative_prompt_attention_mask, use_model_defaults, **kwargs)
#    2318     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2319         input_ids=input_ids,
#    2320         expand_size=generation_config.num_return_sequences,
#    2321         is_encoder_decoder=self.config.is_encoder_decoder,
#    2322         **model_kwargs,
#    2323     )
#    2325     # 12. run sample (it degenerates to greedy search when `generation_config.do_sample=False`)
# -> 2326     result = self._sample(
#    2327         input_ids,
#    2328         logits_processor=prepared_logits_processor,
#    2329         stopping_criteria=prepared_stopping_criteria,
#    2330         generation_config=generation_config,
#    2331         synced_gpus=synced_gpus,
#    2332         streamer=streamer,
#    2333         **model_kwargs,
#    2334     )
#    2336 elif generation_mode in (GenerationMode.BEAM_SAMPLE, GenerationMode.BEAM_SEARCH):
#    2337     # 11. interleave input_ids with `num_beams` additional sequences per batch
#    2338     input_ids, model_kwargs = self._expand_inputs_for_generation(
#    2339         input_ids=input_ids,
#    2340         expand_size=generation_config.num_beams,
#    2341         is_encoder_decoder=self.config.is_encoder_decoder,
#    2342         **model_kwargs,
#    2343     )
#
# File ~/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages/transformers/generation/utils.py:3289, in GenerationMixin._sample(self, input_ids, logits_processor, stopping_criteria, generation_config, synced_gpus, streamer, **model_kwargs)
#    3287     is_prefill = False
#    3288 else:
# -> 3289     outputs = model_forward(**model_inputs, return_dict=True)
#    3291 # synced_gpus: don't waste resources running the code we don't need; kwargs must be updated before skipping
#    3292 model_kwargs = self._update_model_kwargs_for_generation(
#    3293     outputs,
#    3294     model_kwargs,
#    3295     is_encoder_decoder=self.config.is_encoder_decoder,
#    3296 )
#
# File ~/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages/transformers/models/gpt2/modeling_gpt2.py:1062, in GPT2LMHeadModel.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, labels, use_cache, output_attentions, output_hidden_states, return_dict, **kwargs)
#    1054 r"""
#    1055 labels (`torch.LongTensor` of shape `(batch_size, sequence_length)`, *optional*):
#    1056     Labels for language modeling. Note that the labels **are shifted** inside the model, i.e. you can set
#    1057     `labels = input_ids` Indices are selected in `[-100, 0, ..., config.vocab_size]` All labels set to `-100`
#    1058     are ignored (masked), the loss is only computed for labels in `[0, ..., config.vocab_size]`
#    1059 """
#    1060 return_dict = return_dict if return_dict is not None else self.config.use_return_dict
# -> 1062 transformer_outputs = self.transformer(
#    1063     input_ids,
#    1064     past_key_values=past_key_values,
#    1065     attention_mask=attention_mask,
#    1066     token_type_ids=token_type_ids,
#    1067     position_ids=position_ids,
#    1068     head_mask=head_mask,
#    1069     inputs_embeds=inputs_embeds,
#    1070     encoder_hidden_states=encoder_hidden_states,
#    1071     encoder_attention_mask=encoder_attention_mask,
#    1072     use_cache=use_cache,
#    1073     output_attentions=output_attentions,
#    1074     output_hidden_states=output_hidden_states,
#    1075     return_dict=return_dict,
#    1076 )
#    1077 hidden_states = transformer_outputs[0]
#    1079 # Set device for model parallelism
#
# File ~/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1739, in Module._wrapped_call_impl(self, *args, **kwargs)
#    1737     return self._compiled_call_impl(*args, **kwargs)  # type: ignore[misc]
#    1738 else:
# -> 1739     return self._call_impl(*args, **kwargs)
#
# File ~/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages/torch/nn/modules/module.py:1750, in Module._call_impl(self, *args, **kwargs)
#    1745 # If we don't have any hooks, we want to skip the rest of the logic in
#    1746 # this function, and just call forward.
#    1747 if not (self._backward_hooks or self._backward_pre_hooks or self._forward_hooks or self._forward_pre_hooks
#    1748         or _global_backward_pre_hooks or _global_backward_hooks
#    1749         or _global_forward_hooks or _global_forward_pre_hooks):
# -> 1750     return forward_call(*args, **kwargs)
#    1752 result = None
#    1753 called_always_called_hooks = set()
#
# File ~/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages/transformers/models/gpt2/modeling_gpt2.py:829, in GPT2Model.forward(self, input_ids, past_key_values, attention_mask, token_type_ids, position_ids, head_mask, inputs_embeds, encoder_hidden_states, encoder_attention_mask, use_cache, output_attentions, output_hidden_states, return_dict)
#     827     attention_mask = attention_mask if (attention_mask is not None and 0 in attention_mask) else None
#     828 elif _use_sdpa:
# --> 829     attention_mask = _prepare_4d_causal_attention_mask_for_sdpa(
#     830         attention_mask=attention_mask,
#     831         input_shape=(batch_size, input_shape[-1]),
#     832         inputs_embeds=inputs_embeds,
#     833         past_key_values_length=past_length,
#     834     )
#     835 else:
#     836     if attention_mask is not None:
#     837         # We create a 3D attention mask from a 2D tensor mask.
#     838         # Sizes are [batch_size, 1, 1, to_seq_length]
#     839         # So we can broadcast to [batch_size, num_heads, from_seq_length, to_seq_length]
#     840         # this attention mask is more simple than the triangular masking of causal attention
#     841         # used in OpenAI GPT, we just need to prepare the broadcast dimension here.
#
# File ~/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages/transformers/modeling_attn_mask_utils.py:378, in _prepare_4d_causal_attention_mask_for_sdpa(attention_mask, input_shape, inputs_embeds, past_key_values_length, sliding_window)
#     373 # torch.jit.trace, symbolic_trace and torchdynamo with fullgraph=True are unable to capture the controlflow `is_causal=attention_mask is None and q_len > 1`
#     374 # used as an SDPA argument. We keep compatibility with these tracing tools by always using SDPA's `attn_mask` argument in case we are tracing.
#     375 # TODO: For dynamo, rather use a check on fullgraph=True once this is possible (https://github.com/pytorch/pytorch/pull/120400).
#     376 is_tracing = torch.jit.is_tracing() or isinstance(inputs_embeds, torch.fx.Proxy) or is_torchdynamo_compiling()
# --> 378 ignore_causal_mask = AttentionMaskConverter._ignore_causal_mask_sdpa(
#     379     attention_mask=attention_mask,
#     380     inputs_embeds=inputs_embeds,
#     381     past_key_values_length=past_key_values_length,
#     382     sliding_window=sliding_window,
#     383 )
#     385 if ignore_causal_mask:
#     386     expanded_4d_mask = None
#
# File ~/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages/transformers/modeling_attn_mask_utils.py:289, in AttentionMaskConverter._ignore_causal_mask_sdpa(attention_mask, inputs_embeds, past_key_values_length, sliding_window, is_training)
#     287     return False
#     288 elif not is_tracing and torch.all(attention_mask == 1):
# --> 289     if query_length == 1 or key_value_length == query_length:
#     290         # For query_length == 1, causal attention and bi-directional attention are the same.
#     291         ignore_causal_mask = True
#     293     # Unfortunately, for query_length > 1 and key_value_length != query_length, we cannot generally ignore
#     294     # the attention mask, as SDPA causal mask generation may be wrong. We will set `is_causal=False` in
#     295     # SDPA and rely on Transformers attention_mask instead, hence not setting it to None here.
#     296     # Reference: https://github.com/pytorch/pytorch/issues/108108
#     297     # TODO: maybe revisit this with https://github.com/pytorch/pytorch/pull/114823 in PyTorch 2.3.
#
# KeyboardInterrupt:

# %%
# Add a new cell for Text-to-Speech functionality
# !pip3 install gTTS playsound
# Out:
# Collecting gTTS
#   Downloading gTTS-2.5.4-py3-none-any.whl (29 kB)
# Collecting playsound
#   Downloading playsound-1.3.0.tar.gz (7.7 kB)
#   Preparing metadata (setup.py) ... done
# Requirement already satisfied: click<8.2,>=7.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from gTTS) (8.1.8)
# Requirement already satisfied: requests<3,>=2.27 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from gTTS) (2.32.3)
# Requirement already satisfied: idna<4,>=2.5 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from requests<3,>=2.27->gTTS) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from requests<3,>=2.27->gTTS) (2.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from requests<3,>=2.27->gTTS) (3.4.1)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/haidermalik/Documents/Code/CS_NOTES/DataScience/venv/lib/python3.10/site-packages (from requests<3,>=2.27->gTTS) (2025.1.31)
# Building wheels for collected packages: playsound
#   Building wheel for playsound (setup.py) ... done
#   Created wheel for playsound: filename=playsound-1.3.0-py3-none-any.whl size=7021 sha256=d06c060d8071cb5bb552d2be4aa699b23110a76d51df007f0d1cc02a94182ada
#   Stored in directory: /Users/haidermalik/Library/Caches/pip/wheels/24/f9/b3/2ed63b5d2a91bbf7da060acdc294c1335db338ec81f0c76e1b
# Successfully built playsound
# Installing collected packages: playsound, gTTS
# Successfully installed gTTS-2.5.4 playsound-1.3.0
#
# [notice] A new release of pip available: 22.3.1 -> 25.0.1
# [notice] To update, run: pip install --upgrade pip

# %%
from gtts import gTTS
from transformers import pipeline
import os
import IPython.display as ipd

def speak_text(text, lang='en', slow=False):
    """
    Convert text to speech and play it
    
    Parameters:
    - text: The text to convert to speech
    - lang: Language code (default: 'en' for English)
    - slow: Whether to speak slowly (default: False)
    """
    # Create a gTTS object
    tts = gTTS(text=text, lang=lang, slow=slow)
    
    # Save to a temporary file
    temp_file = "tts_output.mp3"
    tts.save(temp_file)
    
    # Play the audio in the notebook
    return ipd.Audio(temp_file, autoplay=True)

# Now let's make our LLM speak its output
def generate_and_speak(prompt, max_length=50):
    """Generate text using LLM and then speak it"""
    
    # Generate text
    text_generator = pipeline("text-generation", model="gpt2", max_length=max_length)
    generated_text = text_generator(prompt)[0]['generated_text']
    
    print("Generated Text:")
    print(generated_text)
    print("\nNow speaking...")
    
    # Return audio player
    return speak_text(generated_text)

# Test with different prompts
generate_and_speak("Artificial intelligence can be defined as")
# Out:
# Device set to use mps:0
# Truncation was not explicitly activated but `max_length` is provided a specific value, please use `truncation=True` to explicitly truncate examples to max length. Defaulting to 'longest_first' truncation strategy. If you encode pairs of sequences (GLUE-style) with the tokenizer you can select this strategy more precisely by providing a specific strategy to `truncation`.
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Generated Text:
# Artificial intelligence can be defined as an approach to a problem. It's a fundamental approach to building and working with systems and not a new and different thing. To do so is to have an intuition of information in a system. Once you have built
#
# Now speaking...
#                 <audio  controls="controls" autoplay="autoplay">
#                     <source src="data:audio/mpeg;base64,..." type="audio/mpeg" />
#                     Your browser does not support the audio element.
#                 </audio>
